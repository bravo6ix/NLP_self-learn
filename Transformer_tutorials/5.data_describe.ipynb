# %% [markdown]
# Transformer多数用作文本翻译

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# `y`根据x推导出来，`x`和`y`之前有关联。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
