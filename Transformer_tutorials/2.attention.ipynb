# %% [markdown]
# ## QKV Attention
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Softmax`(Thinking)` = e^14/(e^14+e^12)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Word vector

# %% [markdown]
# 我欠你1000元。   妈妈叫，开饭啦。
#
# 你欠我1000元。   开饭啦，妈妈叫。
#
# Transformer不同于RNN，在处理数据时不考虑位置信息，所以需要再数据中加入`位置信息`，以让处于`不同位置`的相同数据有所不同，互相区分。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
